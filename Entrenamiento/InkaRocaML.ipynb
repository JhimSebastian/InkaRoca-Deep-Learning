# %% [markdown]
# ## Importando archivos del Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Instalando dependencias

# %%
# !pip install opencv-python

# %% [markdown]
# # Etiquetado Automático de las imágenes

# %%
import cv2
